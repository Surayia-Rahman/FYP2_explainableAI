# %%
import numpy as np
import pandas as pd
# %matplotlib inline

import keras
import keras.utils as np_utils
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.layers.convolutional import Conv2D, MaxPooling2D
import matplotlib.pyplot as plt
#from keras import backend as K
#K.set_image_dim_ordering('th')

from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, accuracy_score
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
# Load the data
airplane = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_airplane.npy')[:5000]
alarm_clock = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_alarm clock.npy')[:5000]
apple = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_apple.npy')[:5000]
arm = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_arm.npy')[:5000]
backpack = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_backpack.npy')[:5000]
banana = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_banana.npy')[:5000]
baseball = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_baseball.npy')[:5000]
basket = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_basket.npy')[:5000]
basketball = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_basketball.npy')[:5000]
bat = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_bat.npy')[:5000]
bed = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_bed.npy')[:5000]
bicycle = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_bicycle.npy')[:5000] 
bird = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_bird.npy')[:5000]
book = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_book.npy')[:5000]
bread = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_bread.npy')[:5000]
bus = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_bus.npy')[:5000]
bush = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_bush.npy')[:5000]
butterfly = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_butterfly.npy')[:5000] 
cactus = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_cactus.npy')[:5000]
cake = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_cake.npy')[:5000]
car = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_car.npy')[:5000] 
cat = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_cat.npy')[:5000]
cell_phone = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_cell phone.npy')[:5000] 
chair = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_chair.npy')[:5000]
circle = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_circle.npy')[:5000]
clock = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_clock.npy')[:5000]
cloud = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_cloud.npy')[:5000]
coffee_cup = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_coffee cup.npy')[:5000] 
cookie = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_cookie.npy')[:5000]
cow = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_cow.npy')[:5000] 
crayon = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_crayon.npy')[:5000]
cup = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_cup.npy')[:5000]
diamond = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_diamond.npy')[:5000] 
dog = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_dog.npy')[:5000] 
donut = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_donut.npy')[:5000]
door = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_door.npy')[:5000]
duck = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_duck.npy')[:5000]
ear = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_ear.npy')[:5000]
elephant = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_elephant.npy')[:5000]
envelope = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_envelope.npy')[:5000]
eye = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_eye.npy')[:5000]
eyeglasses = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_eyeglasses.npy')[:5000]
fan = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_fan.npy')[:5000]
fish = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_fish.npy')[:5000]
flower = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_flower.npy')[:5000]
giraffe = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_giraffe.npy')[:5000]
grapes = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_grapes.npy')[:5000]
grass = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_grass.npy')[:5000]
hand = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_hand.npy')[:5000]
hat = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_hat.npy')[:5000]
helicopter = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_helicopter.npy')[:5000]
hexagon = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_hexagon.npy')[:5000]
hot_air_balloon = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_hot air balloon.npy')[:5000]
house = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_house.npy')[:5000]
ice_cream = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_ice cream.npy')[:5000]
laptop = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_laptop.npy')[:5000]
leaf = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_leaf.npy')[:5000]
leg = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_leg.npy')[:5000]
light_bulb = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_light bulb.npy')[:5000]
lollipop = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_lollipop.npy')[:5000]
moon = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_moon.npy')[:5000]
mountain = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_mountain.npy')[:5000]
mouth = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_mouth.npy')[:5000]
mug = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_mug.npy')[:5000]
nose = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_nose.npy')[:5000]
owl = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_owl.npy')[:5000]
pants = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_pants.npy')[:5000]
pencil = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_pencil.npy')[:5000]
pillow = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_pillow.npy')[:5000]
purse = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_purse.npy')[:5000]
rainbow = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_rainbow.npy')[:5000]
scissors = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_scissors.npy')[:5000]
shoe = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_shoe.npy')[:5000]
shorts = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_shorts.npy')[:5000]
smiley_face = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_smiley face.npy')[:5000]
star = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_star.npy')[:5000]
sun = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_sun.npy')[:5000]
t_shirt = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_t-shirt.npy')[:5000]
table = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_table.npy')[:5000]
teddy_bear = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_teddy-bear.npy')[:5000]
train = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_train.npy')[:5000]
tree = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_tree.npy')[:5000]
umbrella = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_umbrella.npy')[:5000]
wheel = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_wheel.npy')[:5000]
wristwatch = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_wristwatch.npy')[:5000]
zigzag = np.load('C:/Users/Surayia Rahman/Downloads/full_numpy_bitmap_zigzag.npy')[:5000]

# %%
airplane = np.c_[airplane, np.zeros(len(airplane))]
alarm_clock = np.c_[alarm_clock, np.ones(len(alarm_clock))]
apple = np.c_[apple, 2*np.ones(len(apple))]
arm = np.c_[arm, 3*np.ones(len(arm))]
backpack = np.c_[backpack, 4*np.ones(len(backpack))]
banana = np.c_[banana, 5*np.ones(len(banana))]
baseball = np.c_[baseball, 6*np.ones(len(baseball))]
basket = np.c_[basket, 7*np.ones(len(basket))]
basketball = np.c_[basketball, 8*np.ones(len(basketball))]
bat = np.c_[bat, 9*np.ones(len(bat))]
bed = np.c_[bed, 10*np.ones(len(bed))]
bicycle = np.c_[bicycle, 11*np.ones(len(bicycle))]
bird = np.c_[bird, 12*np.ones(len(bird))]
book = np.c_[book, 13*np.ones(len(book))]
bread = np.c_[bread, 14*np.ones(len(bread))]
bus = np.c_[bus, 15*np.ones(len(bus))]
bush = np.c_[bush, 16*np.ones(len(bush))]
butterfly = np.c_[butterfly, 17*np.ones(len(butterfly))]
cactus = np.c_[cactus, 18*np.ones(len(cactus))]
cake = np.c_[cake, 19*np.ones(len(cake))]
car = np.c_[car, 20*np.ones(len(car))]
cat = np.c_[cat, 21*np.ones(len(cat))]
cell_phone = np.c_[cell_phone, 22*np.ones(len(cell_phone))]
chair = np.c_[chair, 23*np.ones(len(chair))]
circle = np.c_[circle, 24*np.ones(len(circle))]
clock = np.c_[clock, 25*np.ones(len(clock))]
cloud = np.c_[cloud, 26*np.ones(len(cloud))]
coffee_cup = np.c_[coffee_cup, 27*np.ones(len(coffee_cup))]
cookie = np.c_[cookie, 28*np.ones(len(cookie))]
cow = np.c_[cow, 29*np.ones(len(cow))]
crayon = np.c_[crayon, 30*np.ones(len(crayon))]
cup = np.c_[cup, 31*np.ones(len(cup))]
diamond = np.c_[diamond, 32*np.ones(len(diamond))]
dog = np.c_[dog, 33*np.ones(len(dog))]
donut = np.c_[donut, 34*np.ones(len(donut))]
door = np.c_[door, 35*np.ones(len(door))]
duck = np.c_[duck, 36*np.ones(len(duck))]
ear = np.c_[ear, 37*np.ones(len(ear))]
elephant = np.c_[elephant, 38*np.ones(len(elephant))]
envelope = np.c_[envelope, 39*np.ones(len(envelope))]
eye = np.c_[eye, 40*np.ones(len(eye))]
eyeglasses = np.c_[eyeglasses, 41*np.ones(len(eyeglasses))]
fan = np.c_[fan, 42*np.ones(len(fan))]
fish = np.c_[fish, 43*np.ones(len(fish))]
flower = np.c_[flower, 44*np.ones(len(flower))]
giraffe = np.c_[giraffe, 45*np.ones(len(giraffe))]
grapes = np.c_[grapes, 46*np.ones(len(grapes))]
grass = np.c_[grass, 47*np.ones(len(grass))]
hand = np.c_[hand, 48*np.ones(len(hand))]
hat = np.c_[hat, 49*np.ones(len(hat))]
helicopter = np.c_[helicopter, 50*np.ones(len(helicopter))]
hexagon = np.c_[hexagon, 51*np.ones(len(hexagon))]
hot_air_balloon = np.c_[hot_air_balloon, 52*np.ones(len(hot_air_balloon))]
house = np.c_[house, 53*np.ones(len(house))]
ice_cream = np.c_[ice_cream, 54*np.ones(len(ice_cream))]
laptop = np.c_[laptop, 55*np.ones(len(laptop))]
leaf = np.c_[leaf, 56*np.ones(len(leaf))]
leg = np.c_[leg, 57*np.ones(len(leg))]
light_bulb = np.c_[light_bulb, 58*np.ones(len(light_bulb))]
lollipop = np.c_[lollipop, 59*np.ones(len(lollipop))]
moon = np.c_[moon, 60*np.ones(len(moon))]
mountain = np.c_[mountain, 61*np.ones(len(mountain))]
mouth = np.c_[mouth, 62*np.ones(len(mouth))]
mug = np.c_[mug, 63*np.ones(len(mug))]
nose = np.c_[nose, 64*np.ones(len(nose))]
owl = np.c_[owl, 65*np.ones(len(owl))]
pants = np.c_[pants, 66*np.ones(len(pants))]
pencil = np.c_[pencil, 67*np.ones(len(pencil))]
pillow = np.c_[pillow, 68*np.ones(len(pillow))]
purse = np.c_[purse, 69*np.ones(len(purse))]
rainbow = np.c_[rainbow, 70*np.ones(len(rainbow))]
scissors = np.c_[scissors, 71*np.ones(len(scissors))]
shoe = np.c_[shoe, 72*np.ones(len(shoe))]
shorts = np.c_[shorts, 73*np.ones(len(shorts))]
smiley_face = np.c_[smiley_face, 74*np.ones(len(smiley_face))]
star = np.c_[star, 75*np.ones(len(star))]
sun = np.c_[sun, 76*np.ones(len(sun))]
t_shirt = np.c_[t_shirt, 77*np.ones(len(t_shirt))]
table = np.c_[table, 78*np.ones(len(table))]
teddy_bear = np.c_[teddy_bear, 79*np.ones(len(teddy_bear))]
train = np.c_[train, 80*np.ones(len(train))]
tree = np.c_[tree, 81*np.ones(len(tree))]
umbrella = np.c_[umbrella, 82*np.ones(len(umbrella))]
wheel = np.c_[wheel, 83*np.ones(len(wheel))]
wristwatch = np.c_[wristwatch, 84*np.ones(len(wristwatch))]
zigzag = np.c_[zigzag, 85*np.ones(len(zigzag))]

# %%
def plot_samples(input_array, rows=4, cols=5, title=''):
    '''
    Function to plot 28x28 pixel drawings that are stored in a numpy array.
    Specify how many rows and cols of pictures to display (default 4x5).  
    If the array contains less images than subplots selected, surplus subplots remain empty.
    '''
    fig, ax = plt.subplots(figsize=(cols,rows))
    ax.axis('off')
    plt.title(title)

    for i in list(range(0, min(len(input_array),(rows*cols)) )):      
        a = fig.add_subplot(rows,cols,i+1)
        imgplot = plt.imshow(input_array[i,:784].reshape((28,28)), cmap='gray_r', interpolation='nearest')
        plt.xticks([])
        plt.yticks([])

# %%
plot_samples(eye, title='Sample eye drawings\n')

# %%
plot_samples(smiley_face, title='Sample eye drawings\n')

# %%
# Merging arrays and splitting the features and labels
y = np.concatenate((airplane[:, -1], alarm_clock[:, -1], apple[:, -1], arm[:, -1], backpack[:, -1], banana[:, -1], baseball[:, -1], basket[:, -1], basketball[:, -1], bat[:, -1], bed[:, -1], bicycle[:, -1], bird[:, -1], book[:, -1], bread[:, -1], bus[:, -1], bush[:, -1], butterfly[:, -1], cactus[:, -1], cake[:, -1], car[:, -1], cat[:, -1], cell_phone[:, -1], chair[:, -1], circle[:, -1], clock[:, -1], cloud[:, -1], coffee_cup[:, -1], cookie[:, -1], cow[:, -1], crayon[:, -1], cup[:, -1], diamond[:, -1], dog[:, -1], donut[:, -1], door[:, -1], duck[:, -1], ear[:, -1], elephant[:, -1], envelope[:, -1], eye[:, -1], eyeglasses[:, -1], fan[:, -1], fish[:, -1], flower[:, -1], giraffe[:, -1], grapes[:, -1], grass[:, -1], hand[:, -1], hat[:, -1], helicopter[:, -1], hexagon[:, -1], hot_air_balloon[:, -1], house[:, -1], ice_cream[:, -1], laptop[:, -1], leaf[:, -1], leg[:, -1], light_bulb[:, -1], lollipop[:, -1], moon[:, -1], mountain[:, -1], mouth[:, -1], mug[:, -1], nose[:, -1], owl[:, -1], pants[:, -1], pencil[:, -1], pillow[:, -1], purse[:, -1], rainbow[:, -1], scissors[:, -1], shoe[:, -1], shorts[:, -1], smiley_face[:, -1], star[:, -1], sun[:, -1], t_shirt[:, -1], table[:, -1], teddy_bear[:, -1], train[:, -1], tree[:, -1], umbrella[:, -1], wheel[:, -1], wristwatch[:, -1], zigzag[:, -1])).astype('float32') # the last column

X = np.concatenate((airplane[:, :-1], alarm_clock[:, :-1], apple[:, :-1], arm[:, :-1], backpack[:, :-1], banana[:, :-1], baseball[:, :-1], basket[:, :-1], basketball[:, :-1], bat[:, :-1], bed[:, :-1], bicycle[:, :-1], bird[:, :-1], book[:, :-1], bread[:, :-1], bus[:, :-1], bush[:, :-1], butterfly[:, :-1], cactus[:, :-1], cake[:, :-1], car[:, :-1], cat[:, :-1], cell_phone[:, :-1], chair[:, :-1], circle[:, :-1], clock[:, :-1], cloud[:, :-1], coffee_cup[:, :-1], cookie[:, :-1], cow[:, :-1], crayon[:, :-1], cup[:, :-1], diamond[:, :-1], dog[:, :-1], donut[:, :-1], door[:, :-1], duck[:, :-1], ear[:, :-1], elephant[:, :-1], envelope[:, :-1], eye[:, :-1], eyeglasses[:, :-1], fan[:, :-1], fish[:, :-1], flower[:, :-1], giraffe[:, :-1], grapes[:, :-1], grass[:, :-1], hand[:, :-1], hat[:, :-1], helicopter[:, :-1], hexagon[:, :-1], hot_air_balloon[:, :-1], house[:, :-1], ice_cream[:, :-1], laptop[:, :-1], leaf[:, :-1], leg[:, :-1], light_bulb[:, :-1], lollipop[:, :-1], moon[:, :-1], mountain[:, :-1], mouth[:, :-1], mug[:, :-1], nose[:, :-1], owl[:, :-1], pants[:, :-1], pencil[:, :-1], pillow[:, :-1], purse[:, :-1], rainbow[:, :-1], scissors[:, :-1], shoe[:, :-1], shorts[:, :-1], smiley_face[:, :-1], star[:, :-1], sun[:, :-1], t_shirt[:, :-1], table[:, :-1], teddy_bear[:, :-1], train[:, :-1], tree[:, :-1], umbrella[:, :-1], wheel[:, :-1], wristwatch[:, :-1], zigzag[:, :-1])).astype('float32') # all columns but the last

# %%
X_train,X_test, y_train, y_test = train_test_split(X/255., y, test_size = 0.2, random_state =0)

# %%
#one hot encoding the output
# one hot encode outputs
y_train_cnn = np_utils.to_categorical(y_train)
y_test_cnn = np_utils.to_categorical(y_test)
num_classes = y_test_cnn.shape[1]

# %%
# reshape to be [samples][pixels][width][height]
X_train_cnn = X_train.reshape(X_train.shape[0], 28, 28,1).astype('float32')
X_test_cnn = X_test.reshape(X_test.shape[0], 28, 28,1).astype('float32')

# %%
def cnn_model():
    # create model
    model = Sequential()
    model.add(Conv2D(30, (3, 3), input_shape=(28, 28,1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(15, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
# %%time
np.random.seed(0)
# build the model
model_cnn = cnn_model()
# Fit the model
model_cnn.fit(X_train_cnn, y_train_cnn, validation_data=(X_test_cnn, y_test_cnn), epochs=19, batch_size=200)
# Final evaluation of the model
scores = model_cnn.evaluate(X_test_cnn, y_test_cnn, verbose=0)
print('Final CNN accuracy: ', scores[1])
# Out:
# Epoch 1/19
# 1720/1720 [==============================] - 69s 39ms/step - loss: 1.9441 - accuracy: 0.5168 - val_loss: 1.3368 - val_accuracy: 0.6618
# Epoch 2/19
# 1720/1720 [==============================] - 72s 42ms/step - loss: 1.3367 - accuracy: 0.6556 - val_loss: 1.1813 - val_accuracy: 0.6964
# Epoch 3/19
# 1720/1720 [==============================] - 72s 42ms/step - loss: 1.1984 - accuracy: 0.6877 - val_loss: 1.0639 - val_accuracy: 0.7252
# Epoch 4/19
# 1720/1720 [==============================] - 72s 42ms/step - loss: 1.1258 - accuracy: 0.7059 - val_loss: 1.0127 - val_accuracy: 0.7377
# Epoch 5/19
# 1720/1720 [==============================] - 72s 42ms/step - loss: 1.0783 - accuracy: 0.7164 - val_loss: 0.9922 - val_accuracy: 0.7417
# Epoch 6/19
# 1720/1720 [==============================] - 73s 42ms/step - loss: 1.0438 - accuracy: 0.7252 - val_loss: 0.9570 - val_accuracy: 0.7496
# Epoch 7/19
# ...

# %%
y_pred_proba_cnn = model_cnn.predict(X_test_cnn, verbose=0)
y_pred_cnn = np.argmax(y_pred_proba_cnn, axis=1)

from sklearn import metrics
c_matrix = metrics.confusion_matrix(y_test, y_pred_cnn)

# %%
import seaborn as sns
def confusion_matrix(confusion_matrix, class_names, figsize = (10,7), fontsize=14):
    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names, 
    )
    fig = plt.figure(figsize=figsize)
    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d")
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
class_names = ['airplane', 'alarm_clock', 'apple', 'arm', 'backpack', 'banana', 'baseball', 'basket', 'basketball', 'bat', 'bed', 'bicycle', 'bird', 'book', 'bread', 'bus', 'bush', 'butterfly', 'cactus', 'cake', 'car', 'cat', 'cell_phone', 'chair', 'circle', 'clock', 'cloud', 'coffee_cup', 'cookie', 'cow', 'crayon', 'cup', 'diamond', 'dog', 'donut', 'door', 'duck', 'ear', 'elephant', 'envelope', 'eye', 'eyeglasses', 'fan', 'fish', 'flower', 'giraffe', 'grapes', 'grass', 'hand', 'hat', 'helicopter', 'hexagon', 'hot_air_balloon', 'house', 'ice_cream', 'laptop', 'leaf', 'leg', 'light_bulb', 'lollipop', 'moon', 'mountain', 'mouth', 'mug', 'nose', 'owl', 'pants', 'pencil', 'pillow', 'purse', 'rainbow', 'scissors', 'shoe', 'shorts', 'smiley_face', 'star', 'sun', 't_shirt', 'table', 'teddy_bear', 'train', 'tree', 'umbrella', 'wheel', 'wristwatch', 'zigzag']

confusion_matrix(c_matrix, class_names, figsize = (20,15), fontsize=8)

# %%
num_classes = len(np.unique(y_test))
print("Number of unique classes:", num_classes)
# Out:
# Number of unique classes: 86

# %%
#Misclassification when y_pred and y_test are different.
misclassified = X_test[y_pred_cnn != y_test]
plot_samples(misclassified, rows=10, cols=5, title='')

# %%
# !pip install streamlit
# Out:
# ...
#   Obtaining dependency information for streamlit from https://files.pythonhosted.org/packages/0e/86/69fdac2ec6852304bda08e5af5b72dfa6e74dc0b3cef0d7c1e19994388ae/streamlit-1.35.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for altair<6,>=4.0 from https://files.pythonhosted.org/packages/46/30/2118537233fa72c1d91a81f5908a7e843a6601ccc68b76838ebc4951505f/altair-5.3.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for blinker<2,>=1.0.0 from https://files.pythonhosted.org/packages/bb/2a/10164ed1f31196a2f7f3799368a821765c62851ead0e630ab52b8e14b4d0/blinker-1.8.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for rich<14,>=10.14.0 from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
# ...

# %%
# Define Streamlit app
import streamlit as st
import numpy as np
from PIL import Image
from keras.models import load_model
import cv2

# %%
# Save the trained model to a file
model_cnn.save('C:/Users/Surayia Rahman/Downloads/cnn_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/Surayia Rahman/Downloads/cnn_model\assets
# INFO:tensorflow:Assets written to: C:/Users/Surayia Rahman/Downloads/cnn_model\assets

# %%
model = load_model('C:/Users/Surayia Rahman/Downloads/cnn_model')

# %%
# Function to preprocess the image
def preprocess_image(image):
    # Resize the image to (28, 28) and convert to grayscale
    image = cv2.resize(image, (28, 28))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Reshape the image to (1, 28, 28, 1)
    image = np.expand_dims(image, axis=0)
    image = np.expand_dims(image, axis=-1)
    # Normalize the image
    image = image / 255.0
    return image

# %%
# Streamlit app
def main():
    st.title("Draw and Let the Model Predict")
    
    # Draw canvas to let the user draw
    canvas = st.image(np.zeros((300, 300)), caption='Draw Here', use_column_width=True, channels='L', clamp=True)
    
    # Button to predict
    if st.button('Predict'):
        # Convert canvas to image
        img_data = canvas.to_array()
        # Preprocess the image
        img = preprocess_image(img_data)
        # Make prediction
        prediction = model.predict(img)
        # Get the predicted digit
        predicted_digit = np.argmax(prediction)
        st.write(f"Predicted Digit: {predicted_digit}")

if __name__ == '__main__':
    main()
# Out:
# 2024-06-09 18:21:39.552
# ...
#   command:
#
#     streamlit run C:\Users\Surayia Rahman\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
